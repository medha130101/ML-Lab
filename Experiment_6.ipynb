# %% [markdown]
# <a href="https://colab.research.google.com/github/medha130101/ML-Lab/blob/main/Experiment_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
df  = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Datasets/Stock.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 symbol                       date    close     high     low  \
# 0           0   AAPL  2015-05-27 00:00:00+00:00  132.045  132.260  130.05
# 1           1   AAPL  2015-05-28 00:00:00+00:00  131.780  131.950  131.10
# 2           2   AAPL  2015-05-29 00:00:00+00:00  130.280  131.450  129.90
# 3           3   AAPL  2015-06-01 00:00:00+00:00  130.535  131.390  130.05
# 4           4   AAPL  2015-06-02 00:00:00+00:00  129.960  130.655  129.32
#
#      open    volume    adjClose     adjHigh      adjLow     adjOpen  \
# 0  130.34  45833246  121.682558  121.880685  119.844118  120.111360
# 1  131.86  30733309  121.438354  121.595013  120.811718  121.512076
# 2  131.23  50884452  120.056069  121.134251  119.705890  120.931516
# 3  131.20  32112797  120.291057  121.078960  119.844118  120.903870
# 4  129.86  33667627  119.761181  120.401640  119.171406  119.669029
#
#    adjVolume  divCash  splitFactor
# 0   45833246      0.0          1.0
# 1   30733309      0.0          1.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   1258 non-null   int64
#  1   symbol       1258 non-null   object
#  2   date         1258 non-null   object
#  3   close        1258 non-null   float64
#  4   high         1258 non-null   float64
#  5   low          1258 non-null   float64
#  6   open         1258 non-null   float64
#  7   volume       1258 non-null   int64
#  8   adjClose     1258 non-null   float64
#  9   adjHigh      1258 non-null   float64
#  10  adjLow       1258 non-null   float64
#  11  adjOpen      1258 non-null   float64
#  12  adjVolume    1258 non-null   int64
#  13  divCash      1258 non-null   float64
#  14  splitFactor  1258 non-null   float64
# dtypes: float64(10), int64(3), object(2)
# memory usage: 147.5+ KB

# %%
df.shape
# Out:
# (1258, 15)

# %%
df.columns.values
# Out:
# array(['Unnamed: 0', 'symbol', 'date', 'close', 'high', 'low', 'open',
#        'volume', 'adjClose', 'adjHigh', 'adjLow', 'adjOpen', 'adjVolume',
#        'divCash', 'splitFactor'], dtype=object)

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
corr = df.corr().round(2)
#mask = np.zeros_like(corr,dtype = np.bool)
#mask[np.triu_indices_from(mask)] = True
# Set the size of figure
f,ax = plt.subplots(figsize = (20,20))
# Define Custom Colormap
cmap = sns.diverging_palette(220,10,as_cmap = True)
# Draw the HeatMap
sns.heatmap(corr,cmap = "coolwarm",vmin = -1, vmax = 1, center = 0,square = True,linewidths = .5, cbar_kws = {"shrink":0.5},annot=True)
plt.tight_layout()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,5))
plt.plot(df['close'],label='closeHistory')
plt.show()

# %%
df.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
df['Date']= pd.to_datetime(df.date, format= '%Y-%m-%d')
df.index = df['Date']
df.head()
# Out:
#                           symbol                       date    close     high  \
# Date
# 2015-05-27 00:00:00+00:00   AAPL  2015-05-27 00:00:00+00:00  132.045  132.260
# 2015-05-28 00:00:00+00:00   AAPL  2015-05-28 00:00:00+00:00  131.780  131.950
# 2015-05-29 00:00:00+00:00   AAPL  2015-05-29 00:00:00+00:00  130.280  131.450
# 2015-06-01 00:00:00+00:00   AAPL  2015-06-01 00:00:00+00:00  130.535  131.390
# 2015-06-02 00:00:00+00:00   AAPL  2015-06-02 00:00:00+00:00  129.960  130.655
#
#                               low    open    volume    adjClose     adjHigh  \
# Date
# 2015-05-27 00:00:00+00:00  130.05  130.34  45833246  121.682558  121.880685
# 2015-05-28 00:00:00+00:00  131.10  131.86  30733309  121.438354  121.595013
# 2015-05-29 00:00:00+00:00  129.90  131.23  50884452  120.056069  121.134251
# 2015-06-01 00:00:00+00:00  130.05  131.20  32112797  120.291057  121.078960
# 2015-06-02 00:00:00+00:00  129.32  129.86  33667627  119.761181  120.401640
#
# ...

# %%
data= df.sort_index(ascending = True, axis = 0)
new_data = pd.DataFrame(index = range(0, len(df)), columns=['Date', 'Close'])
new_data.head()
# Out:
#   Date Close
# 0  NaN   NaN
# 1  NaN   NaN
# 2  NaN   NaN
# 3  NaN   NaN
# 4  NaN   NaN

# %%
for i in range(0, len(data)):
  new_data['Date'][i] = data['Date'][i]
  new_data['Close'][i] = data['close'][i]
new_data.head()
# Out:
#                         Date    Close
# 0  2015-05-27 00:00:00+00:00  132.045
# 1  2015-05-28 00:00:00+00:00   131.78
# 2  2015-05-29 00:00:00+00:00   130.28
# 3  2015-06-01 00:00:00+00:00  130.535
# 4  2015-06-02 00:00:00+00:00   129.96

# %%
dataset = new_data.values
dataset.shape
# Out:
# (1258, 2)

# %%
# !pip install -Uqq fastbook
import fastbook 
fastbook.setup_book()
from fastai.tabular.all import *
add_datepart(new_data, 'Date')
new_data.head()
# Out:
#      Close  Year  Month  Week  Day  Dayofweek  Dayofyear  Is_month_end  \
# 0  132.045  2015      5    22   27          2        147         False
# 1   131.78  2015      5    22   28          3        148         False
# 2   130.28  2015      5    22   29          4        149         False
# 3  130.535  2015      6    23    1          0        152         False
# 4   129.96  2015      6    23    2          1        153         False
#
#    Is_month_start  Is_quarter_end  Is_quarter_start  Is_year_end  \
# 0           False           False             False        False
# 1           False           False             False        False
# 2           False           False             False        False
# 3            True           False             False        False
# 4           False           False             False        False
#
#    Is_year_start       Elapsed
# 0          False  1.432685e+09
# 1          False  1.432771e+09
# 2          False  1.432858e+09
# ...

# %%
new_data.drop('Elapsed', axis = 1, inplace = True)

# %%
new_data.head()
# Out:
#      Close  Year  Month  Week  Day  Dayofweek  Dayofyear  Is_month_end  \
# 0  132.045  2015      5    22   27          2        147         False
# 1   131.78  2015      5    22   28          3        148         False
# 2   130.28  2015      5    22   29          4        149         False
# 3  130.535  2015      6    23    1          0        152         False
# 4   129.96  2015      6    23    2          1        153         False
#
#    Is_month_start  Is_quarter_end  Is_quarter_start  Is_year_end  \
# 0           False           False             False        False
# 1           False           False             False        False
# 2           False           False             False        False
# 3            True           False             False        False
# 4           False           False             False        False
#
#    Is_year_start
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False

# %%
train = new_data[:987]
valid = new_data[987:]
x_train = train.drop('Close', axis=1)
y_train = train['Close']
x_valid = valid.drop('Close', axis=1)
y_valid = valid['Close']
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators = 10, random_state = 0)
model.fit(x_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=0)

# %%
preds = model.predict(x_valid)
rms=np.sqrt(np.mean(np.power((np.array(y_valid)-np.array(preds)),2)))
rms
# Out:
# 79.98630012875844

# %%
valid.head()
# Out:
#       Close  Year  Month  Week  Day  Dayofweek  Dayofyear  Is_month_end  \
# 987  204.61  2019      4    18   29          0        119         False
# 988  200.67  2019      4    18   30          1        120          True
# 989  210.52  2019      5    18    1          2        121         False
# 990  209.15  2019      5    18    2          3        122         False
# 991  211.75  2019      5    18    3          4        123         False
#
#      Is_month_start  Is_quarter_end  Is_quarter_start  Is_year_end  \
# 987           False           False             False        False
# 988           False           False             False        False
# 989            True           False             False        False
# 990           False           False             False        False
# 991           False           False             False        False
#
#      Is_year_start
# 987          False
# 988          False
# 989          False
# 990          False
# 991          False

# %%
x = preds
y = valid['Close']
y = np.array(y)
plt.plot(y)
plt.plot(x)

# %%
# End
